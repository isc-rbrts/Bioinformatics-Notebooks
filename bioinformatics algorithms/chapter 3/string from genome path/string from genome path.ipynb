# %%
f = open("dataset_865398_3.txt","r")

path = [str(x) for x in next(f).split()]

def StringFromGenomePath(path):
    Text = path[0]
    for i in range(1, len(path)):
        Text += path[i][-1]
        
    return Text

print(StringFromGenomePath(path))

f.close()
# Out:
# ...
