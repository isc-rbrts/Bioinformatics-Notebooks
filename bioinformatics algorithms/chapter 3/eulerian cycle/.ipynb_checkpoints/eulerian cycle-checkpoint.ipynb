# %%
from collections import defaultdict
import copy

f = open("dataset_865403_2.txt","r")

graph = defaultdict(list)
while line := f.readline():
    node = line.split(':')
    for x in node[1].split():
        graph[int(node[0])].append(int(x))

#print(graph[list(graph.keys())[2]][0])
"""
def EulerianCycle(graph):
    visited = defaultdict(int)
    cycle = list()
    
    for key in graph:
        if visited[key] == 1:
            next
            
        curr_cycle = list()
        nodes_with_unused_edges = defaultdict(list)
        curr_node = key
        
        while not visited[curr_node]:
            visited[curr_node] = 1
            for i in range(len(graph[curr_node])):
                neighbor = graph[curr_node][i]
                
                if not visited[neighbor]:
                    curr_node
      

def EulerianCycle(graph):
    V = list()
    E = list()
    
    for key in graph:
        V.append(key)
        for i in range(len(graph[key])):
            E.append((key, graph[key][i]))
    
    A = copy.deepcopy(graph)
    K = list()
    L = list()
    
    used_vertex = defaultdict(int)
    edge_pointer_per_vertex = defaultdict(int)
    new_edge_list = defaultdict(lambda: 1)
    s = list(graph.keys())[0] #first vertex in graph
    
    C = Trace(s, new_edge_list, edge_pointer_per_vertex, A, L)
    
def Trace(v, used_vertex, new_edge_list, edge_pointer_per_vertex, A, L):
    C = list()
    while len(A[v]) != 0:
    
        e = (v, A[v][0])
        A[v].pop(0)
        
        
        if new_edge_list[e] == 0:
            continue
        
        C.append(e)
        edge_pointer_per_vertex[v] = e
        new_edge_list[e] = 0
        v = e[1]
        
        if used_vertex[v] == 0:
            L.append(v)
            
    
    print(C)
    return C
"""

def EulerianCycle(graph):
    edges_per_vertex = dict()
    for key in graph:
        edges_per_vertex[key] = len(graph[key])
    
    L = [] #stack
    K = [] #cycle
    
    s = list(graph.keys())[0] #first vertex in graph
    L.append(s)
    v = s
    
    while len(L) > 0:
        if edges_per_vertex[v] > 0:
            L.append(v)
            u = graph[v][-1]
            edges_per_vertex[v] -= 1
            graph[v].pop
            
            v = u
        else:
            K.append(v)
            v = L[-1]
            L.pop()
            
    return K
    
    
print(EulerianCycle(graph))

fans = open("ans.txt","w")

for key in graph:
    out = str(key) + ": "
    for node in graph[key]:
        out += str(node) + " "
    fans.write(out + "\n") 

f.close()
# Out:
# 8
# 9
# 7
# 52
# 69
# 68
# 75
# 74
# 73
# 68
# 75
# 74
# 73
# 68
# 75
# 69
# 69
# 52
# 52
# 52
# 52
# 7
# 7
# 9
# 8
# 8
# 8
# [75, 68, 73, 74, 75, 68, 73, 74, 75, 68, 69, 69, 69, 52, 52, 52, 52, 52, 7, 7, 7, 9, 9, 8, 8, 8, 8, 0]
